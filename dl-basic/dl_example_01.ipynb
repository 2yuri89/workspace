# %%
# !ls -l
# Out:
# total 8
# drwx------ 6 root root 4096 Dec  5 00:37 drive
# drwxr-xr-x 1 root root 4096 Dec  3 19:31 sample_data

# %%
# %%bash
#
# ls -l
# ls -l drive/MyDrive
# Out:
# total 8
# drwx------ 6 root root 4096 Dec  5 00:37 drive
# drwxr-xr-x 1 root root 4096 Dec  3 19:31 sample_data
# total 1075
# drwx------ 4 root root    4096 Sep 19 01:09 Colab Notebooks
# -rw------- 1 root root 1096221 Nov 26 10:19 geocoded_addresses_20191_1_13129.csv

# %%
import tensorflow as tf
from tensorflow import keras as tf_keras
import sklearn as sk

print(tf.__version__)
print(tf_keras.__version__)
print(sk.__version__)
# Out:
# 2.17.1
# 3.5.0
# 1.5.2

# %%
# prompt: mnist 데이터셋을 사용하는 cnn모델 코드

import tensorflow as tf
from tensorflow import keras as tf_keras
import numpy as np

# MNIST 데이터셋 로드
(x_train, y_train), (x_test, y_test) = tf_keras.datasets.mnist.load_data()

# 데이터 전처리
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)
y_train = tf_keras.utils.to_categorical(y_train, num_classes=10)
y_test = tf_keras.utils.to_categorical(y_test, num_classes=10)

# CNN 모델 구성
model = tf_keras.Sequential([
    tf_keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    tf_keras.layers.MaxPooling2D((2, 2)),
    tf_keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf_keras.layers.MaxPooling2D((2, 2)),
    tf_keras.layers.Flatten(),
    tf_keras.layers.Dense(10, activation='softmax')
])

# 모델 컴파일
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# 모델 학습
model.fit(x_train, y_train, epochs=5, batch_size=32, validation_split=0.1)

# 모델 평가
loss, accuracy = model.evaluate(x_test, y_test, verbose=0)
print('Test Loss:', loss)
print('Test Accuracy:', accuracy)
