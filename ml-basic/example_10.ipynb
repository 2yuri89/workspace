# %% [markdown]
# # 나이브 베이즈 분류기 (NB)

# %% [markdown]
# 스팸인가 아닌가?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

# %%
# 데이터 준비
df = pd.read_csv('data-files/SMSSpamCollection.tsv', sep = "\t", header = None, 
                 names=['target', 'message'])
# sep = "\t" 구분자는 탭이다, header = None 헤더 없다. names=['target', 'message'] 컬럼명으로 추가
df.head()
# Out:
#   target                                            message
# 0    ham  Go until jurong point, crazy.. Available only ...
# 1    ham                      Ok lar... Joking wif u oni...
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3    ham  U dun say so early hor... U c already then say...
# 4    ham  Nah I don't think he goes to usf, he lives aro...

# %%
# 범주형 -> 수치형(순위형/명목형 결정)
# y라서 원핫인코딩 안되고 레이블인코딩
from sklearn.preprocessing import LabelEncoder

df['label'] = LabelEncoder().fit_transform(df['target']) # [] 1차원, [[]] 2차원
df.head()
# Out:
#   target                                            message  label
# 0    ham  Go until jurong point, crazy.. Available only ...      0
# 1    ham                      Ok lar... Joking wif u oni...      0
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...      1
# 3    ham  U dun say so early hor... U c already then say...      0
# 4    ham  Nah I don't think he goes to usf, he lives aro...      0

# %%
# message 전처리 1 (영숫자, 공백을 제외한 나머지 문자는 제거)

import re   # 정규표현식 도구
df['message2'] = df['message'].map(lambda v: re.sub("[^\w\s]", '', v))
# "[]" 목록을 말함. \w - 영숫자\s - 공백, ^\w\s > 영숫자, 공백을 제외한 나머지 모두
df.head(1)
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\w'
# <>:4: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\human\AppData\Local\Temp\ipykernel_11328\1581070043.py:4: SyntaxWarning: invalid escape sequence '\w'
#   df['message2'] = df['message'].map(lambda v: re.sub("[^\w\s]", '', v))
#   target                                            message  label  \
# 0    ham  Go until jurong point, crazy.. Available only ...      0
#
#                                             message2
# 0  Go until jurong point crazy Available only in ...

# %%
# message 전처리 2 : 모두 소문자로 변경

df['message3'] = df['message2'].str.lower()
# 스팸인지 아닌지에 대소문자 중요하지 않아서 모든 영문자를 소문자로 바꾸기
df.head(3)
# Out:
#   target                                            message  label  \
# 0    ham  Go until jurong point, crazy.. Available only ...      0
# 1    ham                      Ok lar... Joking wif u oni...      0
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...      1
#
#                                             message2  \
# 0  Go until jurong point crazy Available only in ...
# 1                            Ok lar Joking wif u oni
# 2  Free entry in 2 a wkly comp to win FA Cup fina...
#
#                                             message3
# 0  go until jurong point crazy available only in ...
# 1                            ok lar joking wif u oni
# 2  free entry in 2 a wkly comp to win fa cup fina...

# %%
# !pip install nltk
# Natural Language tokenizing
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in c:\users\human\appdata\roaming\python\python312\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\human\appdata\roaming\python\python312\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\human\appdata\roaming\python\python312\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\human\appdata\roaming\python\python312\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\human\appdata\roaming\python\python312\site-packages (from nltk) (4.67.0)
# Requirement already satisfied: colorama in c:\users\human\appdata\roaming\python\python312\site-packages (from click->nltk) (0.4.6)

# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\human\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\human\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
# message 전처리 3 : 문장을 토큰의 리스트로 변환
# df['message4'] = df['message3'].map(lambda v: nltk.word_tokenize(v))
df['message4'] = df['message3'].map(nltk.word_tokenize) 
# word_tokenize : 단어별로 구분하라(스페이스나 탭을 기준으로 단어를 나눔)
df.head()
# Out:
#   target                                            message  label  \
# 0    ham  Go until jurong point, crazy.. Available only ...      0
# 1    ham                      Ok lar... Joking wif u oni...      0
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...      1
# 3    ham  U dun say so early hor... U c already then say...      0
# 4    ham  Nah I don't think he goes to usf, he lives aro...      0
#
#                                             message2  \
# 0  Go until jurong point crazy Available only in ...
# 1                            Ok lar Joking wif u oni
# 2  Free entry in 2 a wkly comp to win FA Cup fina...
# 3        U dun say so early hor U c already then say
# 4  Nah I dont think he goes to usf he lives aroun...
#
#                                             message3  \
# 0  go until jurong point crazy available only in ...
# 1                            ok lar joking wif u oni
# 2  free entry in 2 a wkly comp to win fa cup fina...
# 3        u dun say so early hor u c already then say
# 4  nah i dont think he goes to usf he lives aroun...
#
#                                             message4
# 0  [go, until, jurong, point, crazy, available, o...
# 1                     [ok, lar, joking, wif, u, oni]
# 2  [free, entry, in, 2, a, wkly, comp, to, win, f...
# 3  [u, dun, say, so, early, hor, u, c, already, t...
# 4  [nah, i, dont, think, he, goes, to, usf, he, l...

# %%
# message 전처리 4 : 어근 추출 (단어의 활용 표준화)
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()
print(stemmer.stem('apples'), stemmer.stem('apple'))
print(stemmer.stem('go'), stemmer.stem('goes'))

df['message5'] = df['message4'].map(lambda words: [ stemmer.stem(w) for w in words])
df.head()
# Out:
# appl appl
# go goe
#   target                                            message  label  \
# 0    ham  Go until jurong point, crazy.. Available only ...      0
# 1    ham                      Ok lar... Joking wif u oni...      0
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...      1
# 3    ham  U dun say so early hor... U c already then say...      0
# 4    ham  Nah I don't think he goes to usf, he lives aro...      0
#
#                                             message2  \
# 0  Go until jurong point crazy Available only in ...
# 1                            Ok lar Joking wif u oni
# 2  Free entry in 2 a wkly comp to win FA Cup fina...
# 3        U dun say so early hor U c already then say
# 4  Nah I dont think he goes to usf he lives aroun...
#
#                                             message3  \
# 0  go until jurong point crazy available only in ...
# 1                            ok lar joking wif u oni
# 2  free entry in 2 a wkly comp to win fa cup fina...
# 3        u dun say so early hor u c already then say
# 4  nah i dont think he goes to usf he lives aroun...
#
#                                             message4  \
# 0  [go, until, jurong, point, crazy, available, o...
# 1                     [ok, lar, joking, wif, u, oni]
# 2  [free, entry, in, 2, a, wkly, comp, to, win, f...
# 3  [u, dun, say, so, early, hor, u, c, already, t...
# 4  [nah, i, dont, think, he, goes, to, usf, he, l...
#
#                                             message5
# 0  [go, until, jurong, point, crazi, avail, onli,...
# 1                       [ok, lar, joke, wif, u, oni]
# 2  [free, entri, in, 2, a, wkli, comp, to, win, f...
# 3  [u, dun, say, so, earli, hor, u, c, alreadi, t...
# 4  [nah, i, dont, think, he, goe, to, usf, he, li...
