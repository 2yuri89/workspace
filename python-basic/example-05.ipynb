# %% [markdown]
# ##### api활용 - 측정소(선생님과 함께)

# %% [markdown]
# https://www.data.go.kr/tcs/dss/selectApiDataDetailView.do?publicDataPk=15073877

# %%
import requests

# service_key = "YgC6RL7Xuzrbvz7msHuvRG0JZ%2BJxR0E6iUI4qrJNk78%2B5FdBneHQ8wktN9kjkpfJFCUeVtCuvThmYWikuonEuA%3D%3D"
# 인코딩 인증키

service_key = "YgC6RL7Xuzrbvz7msHuvRG0JZ+JxR0E6iUI4qrJNk78+5FdBneHQ8wktN9kjkpfJFCUeVtCuvThmYWikuonEuA=="
# 디코딩 인증키

url = 'http://apis.data.go.kr/B552584/MsrstnInfoInqireSvc/getMsrstnList'
params ={'serviceKey' : service_key, 'returnType' : 'JSON', 'numOfRows' : '500', 'pageNo' : '1'}

response = requests.get(url, params=params)
print(response.content)
# Out:
# b'{"response":{"body":{"totalCount":661,"items":[{"dmX":"37.012575","item":"SO2, CO, O3, NO2, PM10, PM2.5","mangName":"\xed\x95\xad\xeb\xa7\x8c","year":"2019","addr":"\xec\xb6\xa9\xeb\x82\xa8 \xec\x84\x9c\xec\x82\xb0\xec\x8b\x9c \xeb\x8c\x80\xec\x82\xb0\xec\x9d\x8d \xeb\x8c\x80\xec\xa3\xbd\xeb\xa6\xac 1114 \xeb\x8c\x80\xec\x82\xb0\xed\x95\xad \xea\xb3\xb5\xec\x9b\x90\xeb\xb6\x80\xec\xa7\x80","stationName":"\xeb\x8c\x80\xec\x82\xb0\xed\x95\xad","dmY":"126.426621"},{"dmX":"36.00799","item":"SO2, CO, O3, NO2, PM10, PM2.5","mangName":"\xed\x95\xad\xeb\xa7\x8c","year":"2019","addr":"\xec\xb6\xa9\xeb\x82\xa8 \xec\x84\x9c\xec\xb2\x9c\xea\xb5\xb0 \xec\x9e\xa5\xed\x95\xad\xec\x9d\x8d \xec\x9e\xa5\xec\x82\xb0\xeb\xa1\x9c 270-3 \xec\x9e\xa5\xed\x95\xad\xed\x95\xb4\xec\x96\x91\xec\x88\x98\xec\x82\xb0\xec\x82\xac\xeb\xac\xb4\xec\x86\x8c \xec\x98\xa5\xec\x83\x81","stationName":"\xec\x9e\xa5\xed\x95\xad\xed\x95\xad","dmY":"126.690312"},{"dmX":"36.98556","item":"SO2, CO, O3, NO2, PM10, PM2.5","mangN
# ...

# %%
# binary 텍스트를 text 포멧으로 변환하는 작업

dedcoded_response_content = response.content.decode('utf-8')
dedcoded_response_content
# Out:
# '{"response":{"body":{"totalCount":661,"items":[{"dmX":"37.012575","item":"SO2, CO, O3, NO2, PM10, PM2.5","mangName":"항만","year":"2019","addr":"충남 서산시 대산읍 대죽리 1114 대산항 공원부지","stationName":"대산항","dmY":"126.426621"},{"dmX":"36.00799","item":"SO2, CO, O3, NO2, PM10, PM2.5","mangName":"항만","year":"2019","addr":"충남 서천군 장항읍 장산로 270-3 장항해양수산사무소 옥상","stationName":"장항항","dmY":"126.690312"},{"dmX":"36.98556","item":"SO2, CO, O3, NO2, PM10, PM2.5","mangName":"항만","year":"2021","addr":"충남 당진시 송악읍 고대공단2길 79-30 고대관리부두 내","stationName":"평택당진항(당진항)","dmY":"126.746821"},{"dmX":"36.898586","item":"SO2, CO, O3, NO2, PM10, PM2.5","mangName":"항만","year":"2023","addr":"충남 태안군 원북면 발전로 457 한국서부발전내","stationName":"태안항","dmY":"126.239162"},{"dmX":"36.401527","item":"SO2, CO, O3, NO2, PM10, PM2.5","mangName":"항만","year":"2022","addr":"충남 보령시 오천면 오천해안로 89-37 보령발전소 내","stationName":"보령항","dmY":"126.487455"},{"dmX":"36.592906","item":"SO2, CO, O3, NO2, PM10, PM2.5","mangName":"도시대기","year":"2015","addr":"세종 조치원읍 
# ...

# %%
import json

# json string -> dict 변환
dict_content = json.loads(dedcoded_response_content)
dict_content
# Out:
# {'response': {'body': {'totalCount': 661,
#    'items': [{'dmX': '37.012575',
#      'item': 'SO2, CO, O3, NO2, PM10, PM2.5',
#      'mangName': '항만',
#      'year': '2019',
#      'addr': '충남 서산시 대산읍 대죽리 1114 대산항 공원부지',
#      'stationName': '대산항',
#      'dmY': '126.426621'},
#     {'dmX': '36.00799',
#      'item': 'SO2, CO, O3, NO2, PM10, PM2.5',
#      'mangName': '항만',
#      'year': '2019',
#      'addr': '충남 서천군 장항읍 장산로 270-3 장항해양수산사무소 옥상',
#      'stationName': '장항항',
#      'dmY': '126.690312'},
#     {'dmX': '36.98556',
#      'item': 'SO2, CO, O3, NO2, PM10, PM2.5',
#      'mangName': '항만',
#      'year': '2021',
#      'addr': '충남 당진시 송악읍 고대공단2길 79-30 고대관리부두 내',
#      'stationName': '평택당진항(당진항)',
#      'dmY': '126.746821'},
#     {'dmX': '36.898586',
#      'item': 'SO2, CO, O3, NO2, PM10, PM2.5',
#      'mangName': '항만',
#      'year': '2023',
#      'addr': '충남 태안군 원북면 발전로 457 한국서부발전내',
#      'stationName': '태안항',
#      'dmY': '126.239162'},
# ...

# %%
# {'response': {'body': {'totalCount': 661, 'items': [{'dmX': '35.063038'
# response 밑 body 밑 items 에 리스트 있음

dict_content['response']['body']['items']
# Out:
# [{'dmX': '37.012575',
#   'item': 'SO2, CO, O3, NO2, PM10, PM2.5',
#   'mangName': '항만',
#   'year': '2019',
#   'addr': '충남 서산시 대산읍 대죽리 1114 대산항 공원부지',
#   'stationName': '대산항',
#   'dmY': '126.426621'},
#  {'dmX': '36.00799',
#   'item': 'SO2, CO, O3, NO2, PM10, PM2.5',
#   'mangName': '항만',
#   'year': '2019',
#   'addr': '충남 서천군 장항읍 장산로 270-3 장항해양수산사무소 옥상',
#   'stationName': '장항항',
#   'dmY': '126.690312'},
#  {'dmX': '36.98556',
#   'item': 'SO2, CO, O3, NO2, PM10, PM2.5',
#   'mangName': '항만',
#   'year': '2021',
#   'addr': '충남 당진시 송악읍 고대공단2길 79-30 고대관리부두 내',
#   'stationName': '평택당진항(당진항)',
#   'dmY': '126.746821'},
#  {'dmX': '36.898586',
#   'item': 'SO2, CO, O3, NO2, PM10, PM2.5',
#   'mangName': '항만',
#   'year': '2023',
#   'addr': '충남 태안군 원북면 발전로 457 한국서부발전내',
#   'stationName': '태안항',
#   'dmY': '126.239162'},
#  {'dmX': '36.401527',
#   'item': 'SO2, CO, O3, NO2, PM10, PM2.5',
#   'mangName': '항만',
#   'year': '2022',
#   'addr': '충남 보령시 오천면 오천해안로 89-37 보령발전소 내',
# ...

# %%
import pandas as pd

# 판다스 데이터프레임으로 변환
df_content = pd.DataFrame(dict_content['response']['body']['items'])
print(df_content.columns)
print(df_content[['stationName', 'addr']])
# Out:
# Index(['dmX', 'item', 'mangName', 'year', 'addr', 'stationName', 'dmY'], dtype='object')
#     stationName                                   addr
# 0           대산항           충남 서산시 대산읍 대죽리 1114 대산항 공원부지
# 1           장항항      충남 서천군 장항읍 장산로 270-3 장항해양수산사무소 옥상
# 2    평택당진항(당진항)       충남 당진시 송악읍 고대공단2길 79-30 고대관리부두 내
# 3           태안항             충남 태안군 원북면 발전로 457 한국서부발전내
# 4           보령항         충남 보령시 오천면 오천해안로 89-37 보령발전소 내
# ..          ...                                    ...
# 495         본오동  경기도 안산시 상록구 오목로7길 15 본오1동 작은도서관 (본오동)
# 496         원곡동      경기도 안산시 단원구 부부로6길 17 근로자운동장 (원곡동)
# 497        부곡동1          경기 안산시 상록구 성호로 326 부곡동 행정복지센터
# 498         대부동       경기 안산시 단원구 대부중앙로 97-9 대부동 행정복지센터
# 499         호수동             경기 안산시 단원구 안산천남로 119 양지중학교
#
# [500 rows x 2 columns]

# %% [markdown]
# ##### api활용 - 대기오염 통계현황

# %% [markdown]
# * 일자별 미세먼지 (pm10 or pm25) 데이터 조회 및 시각화
# * 일정 기간의 미세먼지 데이터를 조회해서 선그래프로 표시
#     - 일정 기간 : 올해/작년/재작년 1월~9월

# %%
import requests

service_key = "YgC6RL7Xuzrbvz7msHuvRG0JZ+JxR0E6iUI4qrJNk78+5FdBneHQ8wktN9kjkpfJFCUeVtCuvThmYWikuonEuA=="
# 디코딩 인증키

url = 'http://apis.data.go.kr/B552584/ArpltnStatsSvc/getMsrstnAcctoRDyrg'
params ={'serviceKey' : service_key, 'returnType' : 'JSON', 'numOfRows' : '100000', 'pageNo' : '1', 'inqBginDt' : '20220101', 'inqEndDt' : '20241031', 'msrstnName' : '영등포구'}

response = requests.get(url, params=params)
print(response.content)
# Out:
# b'{"response":{"body":{"totalCount":175,"items":[{"msurDt":"2024-05-01","so2Value":".002","coValue":".3","msrstnName":"\xec\x98\x81\xeb\x93\xb1\xed\x8f\xac\xea\xb5\xac","pm10Value":"25","no2Value":".013","o3Value":".047","pm25Value":"16"},{"msurDt":"2024-05-02","so2Value":".003","coValue":".3","msrstnName":"\xec\x98\x81\xeb\x93\xb1\xed\x8f\xac\xea\xb5\xac","pm10Value":"32","no2Value":".022","o3Value":".041","pm25Value":"20"},{"msurDt":"2024-05-03","so2Value":".003","coValue":".4","msrstnName":"\xec\x98\x81\xeb\x93\xb1\xed\x8f\xac\xea\xb5\xac","pm10Value":"41","no2Value":".026","o3Value":".051","pm25Value":"26"},{"msurDt":"2024-05-04","so2Value":".004","coValue":".5","msrstnName":"\xec\x98\x81\xeb\x93\xb1\xed\x8f\xac\xea\xb5\xac","pm10Value":"48","no2Value":".031","o3Value":".065","pm25Value":"33"},{"msurDt":"2024-05-05","so2Value":".002","coValue":".3","msrstnName":"\xec\x98\x81\xeb\x93\xb1\xed\x8f\xac\xea\xb5\xac","pm10Value":"21","no2Value":".013","o3Value":".027","pm25Value":"14"}
# ...

# %%
# binary 텍스트를 text 포멧으로 변환하는 작업

dedcoded_response_content = response.content.decode('utf-8')
dedcoded_response_content
# Out:
# '{"response":{"body":{"totalCount":175,"items":[{"msurDt":"2024-05-01","so2Value":".002","coValue":".3","msrstnName":"영등포구","pm10Value":"25","no2Value":".013","o3Value":".047","pm25Value":"16"},{"msurDt":"2024-05-02","so2Value":".003","coValue":".3","msrstnName":"영등포구","pm10Value":"32","no2Value":".022","o3Value":".041","pm25Value":"20"},{"msurDt":"2024-05-03","so2Value":".003","coValue":".4","msrstnName":"영등포구","pm10Value":"41","no2Value":".026","o3Value":".051","pm25Value":"26"},{"msurDt":"2024-05-04","so2Value":".004","coValue":".5","msrstnName":"영등포구","pm10Value":"48","no2Value":".031","o3Value":".065","pm25Value":"33"},{"msurDt":"2024-05-05","so2Value":".002","coValue":".3","msrstnName":"영등포구","pm10Value":"21","no2Value":".013","o3Value":".027","pm25Value":"14"},{"msurDt":"2024-05-06","so2Value":".002","coValue":".3","msrstnName":"영등포구","pm10Value":"11","no2Value":".008","o3Value":".046","pm25Value":"7"},{"msurDt":"2024-05-07","so2Value":".002","coValue":".4","msrstnName":"영등포구"
# ...

# %%
import json

# json string -> dict 변환
dict_content = json.loads(dedcoded_response_content)
dict_content
# Out:
# {'response': {'body': {'totalCount': 175,
#    'items': [{'msurDt': '2024-05-01',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '영등포구',
#      'pm10Value': '25',
#      'no2Value': '.013',
#      'o3Value': '.047',
#      'pm25Value': '16'},
#     {'msurDt': '2024-05-02',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '영등포구',
#      'pm10Value': '32',
#      'no2Value': '.022',
#      'o3Value': '.041',
#      'pm25Value': '20'},
#     {'msurDt': '2024-05-03',
#      'so2Value': '.003',
#      'coValue': '.4',
#      'msrstnName': '영등포구',
#      'pm10Value': '41',
#      'no2Value': '.026',
#      'o3Value': '.051',
#      'pm25Value': '26'},
#     {'msurDt': '2024-05-04',
#      'so2Value': '.004',
#      'coValue': '.5',
#      'msrstnName': '영등포구',
#      'pm10Value': '48',
#      'no2Value': '.031',
#      'o3Value': '.065',
#      'pm25Value': '33'},
#     {'msurDt': '2024-05-05',
#      'so2Value': '.002',
# ...

# %%
# 리스트 확인하기

print( dict_content['response'].keys() )
print( dict_content['response']['body'].keys() )
print( type(dict_content['response']['body']['items']) )
print( dict_content['response']['body']['items'] )
# Out:
# dict_keys(['body', 'header'])
# dict_keys(['totalCount', 'items', 'pageNo', 'numOfRows'])
# <class 'list'>
# ...

# %%
import pandas as pd

# 판다스 데이터프레임으로 변환
df_content = pd.DataFrame(dict_content['response']['body']['items'])
print(df_content.columns)
# Out:
# Index(['msurDt', 'so2Value', 'coValue', 'msrstnName', 'pm10Value', 'no2Value',
#        'o3Value', 'pm25Value'],
#       dtype='object')

# %%
df_content.info()
df_content.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175 entries, 0 to 174
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   msurDt      175 non-null    object
#  1   so2Value    175 non-null    object
#  2   coValue     175 non-null    object
#  3   msrstnName  175 non-null    object
#  4   pm10Value   175 non-null    object
#  5   no2Value    175 non-null    object
#  6   o3Value     175 non-null    object
#  7   pm25Value   175 non-null    object
# dtypes: object(8)
# memory usage: 11.1+ KB
#        msurDt so2Value coValue msrstnName pm10Value no2Value o3Value pm25Value
# 0  2024-05-01     .002      .3       영등포구        25     .013    .047        16
# 1  2024-05-02     .003      .3       영등포구        32     .022    .041        20
# 2  2024-05-03     .003      .4       영등포구        41     .026    .051        26
# 3  2024-05-04     .004      .5       영등포구        48     .031    .065        33
# ...

# %%
df_content["pm10Value"] = df_content['pm10Value'].map(lambda v : float(v))
df_content["pm25Value"] = df_content['pm25Value'].map(lambda v : float(v))

df_content['msurDt'] = pd.to_datetime(df_content['msurDt'])
df_content = df_content.loc[:, ["msurDt", "pm10Value", "pm25Value"]]

df_content.info()
print( df_content )
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175 entries, 0 to 174
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   msurDt     175 non-null    datetime64[ns]
#  1   pm10Value  175 non-null    float64
#  2   pm25Value  175 non-null    float64
# dtypes: datetime64[ns](1), float64(2)
# memory usage: 4.2 KB
#         msurDt  pm10Value  pm25Value
# 0   2024-05-01       25.0       16.0
# 1   2024-05-02       32.0       20.0
# 2   2024-05-03       41.0       26.0
# 3   2024-05-04       48.0       33.0
# 4   2024-05-05       21.0       14.0
# ..         ...        ...        ...
# 170 2024-10-18       22.0       12.0
# 171 2024-10-19       11.0        5.0
# 172 2024-10-20       12.0        4.0
# 173 2024-10-21       12.0        4.0
# 174 2024-10-22       14.0        5.0
#
# [175 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# 맷플롯립 한글 사용
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False

plt.figure(figsize=(10, 5))
plt.plot(df_content['msurDt'], df_content['pm10Value'], label = '미세먼지')
plt.plot(df_content['msurDt'], df_content['pm25Value'], label = '초미세먼지')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 맷플롯립 한글 사용
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False

plt.figure(figsize=(10, 6))
plt.plot(df_content['msurDt'], df_content['pm10Value'], label = '미세먼지', color = 'blue')
plt.plot(df_content['msurDt'], df_content['pm25Value'], label = '초미세먼지', color = 'red')
plt.plot(df_content['msurDt'], pm10Max, color = 'blue', ls='--', alpha = 0.2, label = '최고미세먼지')
plt.plot(df_content['msurDt'], pm10Min, color = 'blue', ls=':', alpha = 0.2, label = '최저미세먼지')
plt.plot(df_content['msurDt'], pm25Max, color = 'red', ls='--', alpha = 0.2, label = '최고초미세먼지')
plt.plot(df_content['msurDt'], pm25Min, color = 'red', ls=':', alpha = 0.2, label = '최저초미세먼지')

# # plt.text()
# x = df_content['msurDt']
# y1 = df_content['pm10Value']
# y1 = df_content['pm25Value']

# for i in range(len(x)):
#     height = y1[i]
#     plt.legend(x[i], height + 0.25, '%.1f' %height, ha='center', va='bottom', size = 12)
plt.title('영등포구 미세먼지 및 초미세먼지')
plt.legend(loc = 'upper right')
plt.show()

# %%
df_content_may = df_content[:31]
df_content_may.head(1)
df_content_may.tail(1)
# df_content_jun = df_content[31:61]
df_content_jun.head(1)
df_content_jun.tail(1)
# # df_content_jul = df_content[31:61]
# df_content_jul.head(1)
# df_content_jul.tail(1)
# # df_content_aug = df_content[:31]
# df_content_aug.head(1)
# df_content_aug.tail(1)
# # df_content_sep = df_content[:31]
# df_content_sep.head(1)
# df_content_sep.tail(1)
# # df_content_oct = df_content[:31]
# df_content_oc.head(1)
# df_content_oct.tail(1)
# Out:
#        msurDt  pm10Value  pm25Value
# 29 2024-05-30       26.0       16.0
# 30 2024-05-31       22.0       14.0
